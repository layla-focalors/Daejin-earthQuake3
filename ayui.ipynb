# %%
# 패키지 선언
import pymysql
import numpy as np
import pandas as pd

# sql 서버 접속
conn = pymysql.connect(host='localhost', user='root', password='root', db='quake', charset='utf8')
cur = conn.cursor()

# 서비스 테이블에 있는 데이터 가져오기
cur.execute("SELECT * FROM service")

# 데이터 가져와서 노트 리스트로 저장
note = cur.fetchall()
conn.commit()

# %%
# 레벨 변수 선언
levels = []

# 노트에 저장된 데이터 수정
for i in note:
    # print(i[6])
    # print((str(i[6]).split(' '))[0])
    mae = []
    mae.append((i[0],i[1],i[2],i[3],i[4],i[5],(str(i[6]).split(' '))[0]))
    levels.append(mae)
# df = pd.DataFrame({'name of issuer': name, 'cusip':cu})  
print(levels)

# 데이터프레임으로 변환
df = pd.DataFrame(note, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
# df = pd.DataFrame({'ID'})
# Out:
# [[(624, '2023/05/29', '06:59:12', '1', '35.54 N', '129.21 E', '울산')], [(626, '2023/05/27', '02:32:12', '1', '35.46 N', '126.81 E', '전남')], [(628, '2023/05/26', '20:39:54', '1', '35.46 N', '126.81 E', '전남')], [(635, '2023/05/24', '17:15:36', '1', '36.49 N', '129.81 E', '경북')], [(637, '2023/05/24', '05:26:46', '1', '35.04 N', '124.92 E', '전남')], [(638, '2023/05/23', '00:28:35', '1', '36.69 N', '127.78 E', '충북')], [(645, '2023/05/19', '21:08:33', '1', '34.43 N', '125.99 E', '전남')], [(646, '2023/05/19', '16:34:13', '1', '34.43 N', '125.99 E', '전남')], [(649, '2023/05/19', '00:23:33', '1', '34.93 N', '127.17 E', '전남')], [(651, '2023/05/18', '15:39:55', '1', '38.13 N', '127.10 E', '경기')], [(652, '2023/05/18', '02:59:19', '1', '35.36 N', '127.91 E', '경남')], [(660, '2023/05/15', '06:39:25', '1', '35.37 N', '128.03 E', '경남')], [(665, '2023/05/13', '10:14:04', '1', '36.48 N', '128.52 E', '경북')], [(666, '2023/05/12', '17:04:54', '1', '34.79 N', '127.45 E', '전남')], [(667, '2023/05/12', '06:22:25'
# ...

# %%
# 레벨 변수 출력
print(levels)

# %%
print(df.head(10))
# print(df['TimeStamp'].head(10))
# 데이터프레임 상위 10개 데이터 가져오기
# Out:
#         ID        Date TimeStamp level    addr1     addr2 address
# 0      624  2023/05/29  06:59:12     1  35.54 N  129.21 E      울산
# 1      626  2023/05/27  02:32:12     1  35.46 N  126.81 E      전남
# 2      628  2023/05/26  20:39:54     1  35.46 N  126.81 E      전남
# 3      635  2023/05/24  17:15:36     1  36.49 N  129.81 E      경북
# 4      637  2023/05/24  05:26:46     1  35.04 N  124.92 E      전남
# ...    ...         ...       ...   ...      ...       ...     ...
# 2184  7808  2008/09/04  00:44:29     3  35.13 N  125.04 E      전남
# 2185  7810  2008/07/27  21:48:48     2  34.45 N  128.08 E      경남
# 2186  7812  2008/07/23  19:29:57     2  34.49 N  128.04 E      경남
# 2187  7813  2008/07/22  23:11:26     2  35.31 N  129.74 E      울산
# 2188  7817  2008/06/30  03:34:07     2  35.10 N  124.66 E      전남
#
# [2189 rows x 7 columns]

# %%
# 시각화 패키지 선언

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Malgun Gothic'

# Load the example diamonds dataset
# diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
# plt.rcParams['font.family'] = 'C:\\Users\\starl\\Downloads\\nanum-gothic\\NanumGothic.otf'
sns.despine(f, left=True, bottom=True)
# clarity_ranking = ["서울", "울산", "전남", "경북", "전북", "부산"]
plt.gcf().set_size_inches(15, 8)
plt.figure(figsize=(192, 8))
sns.scatterplot(x="Date", y="address",
                # hue="address",
                size="level",
                palette="ch:r=-.2,d=.3_r",
                # hue_order=clarity_ranking,
                sizes=(1, 10), linewidth=0,
                data=df, ax=ax)
# print(df.head(10))
# price = 발생빈도로 변환 / 지역으로 전환 후 지역 데이터를 cut 타입에 지정
# Out:
# C:\Users\starl\AppData\Local\Temp\ipykernel_5496\259291466.py:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="Date", y="address",
# <Axes: xlabel='Date', ylabel='address'>

# %%
import pymysql
import numpy as np
import pandas as pd
# sql서버 코드, 패키지 선언

# sql 서버 접속
conn = pymysql.connect(host='localhost', user='root', password='root', db='quake', charset='utf8')
cur = conn.cursor()

# 지역이 전남, 날짜가 2023-01-01 이상인 데이터 요청
cur.execute("SELECT * FROM service where eq_location = '전남' and eq_date >= '2023-01-01'")
note = cur.fetchall()
# 수신한 데이터 저장

# for i in note:
    # print(i)
    
    
# 데이터프레임으로 변환
df = pd.DataFrame(note, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
print(df.head(10))

# 상위 헤드 10개 데이터 출력

# df = pd.DataFrame(note, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
# print(df.head('timestamp'))

conn.commit()

# seaborn 패키지 출력
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# 시각화
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="addr1", y="addr2",
                # hue="cla",
                size="level",
                palette="ch:r=-.2,d=.3_r",
                # hue_order=clarity_ranking,
                sizes=(1, 20), linewidth=0,
                data=df, ax=ax)
# Out:
#     ID        Date TimeStamp level    addr1     addr2 address
# 0  626  2023/05/27  02:32:12     1  35.46 N  126.81 E      전남
# 1  628  2023/05/26  20:39:54     1  35.46 N  126.81 E      전남
# 2  637  2023/05/24  05:26:46     1  35.04 N  124.92 E      전남
# 3  645  2023/05/19  21:08:33     1  34.43 N  125.99 E      전남
# 4  646  2023/05/19  16:34:13     1  34.43 N  125.99 E      전남
# 5  649  2023/05/19  00:23:33     1  34.93 N  127.17 E      전남
# 6  666  2023/05/12  17:04:54     1  34.79 N  127.45 E      전남
# 7  706  2023/05/02  19:08:12     1  35.09 N  125.07 E      전남
# 8  752  2023/04/19  13:40:19     1  34.07 N  124.60 E      전남
# 9  760  2023/04/17  17:45:02     1  35.41 N  125.97 E      전남
# C:\Users\starl\AppData\Local\Temp\ipykernel_5496\3186230818.py:34: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="addr1", y="addr2",
# <Axes: xlabel='addr1', ylabel='addr2'>

# %%
print(df.head(10))
# 데이터 상위 헤더 출력
# Out:
#     ID        Date TimeStamp level    addr1     addr2 address
# 0  626  2023/05/27  02:32:12     1  35.46 N  126.81 E      전남
# 1  628  2023/05/26  20:39:54     1  35.46 N  126.81 E      전남
# 2  637  2023/05/24  05:26:46     1  35.04 N  124.92 E      전남
# 3  645  2023/05/19  21:08:33     1  34.43 N  125.99 E      전남
# 4  646  2023/05/19  16:34:13     1  34.43 N  125.99 E      전남
# 5  649  2023/05/19  00:23:33     1  34.93 N  127.17 E      전남
# 6  666  2023/05/12  17:04:54     1  34.79 N  127.45 E      전남
# 7  706  2023/05/02  19:08:12     1  35.09 N  125.07 E      전남
# 8  752  2023/04/19  13:40:19     1  34.07 N  124.60 E      전남
# 9  760  2023/04/17  17:45:02     1  35.41 N  125.97 E      전남

# %%
import pymysql
# sql 패키지 선언 및 데이터 요청

# 2023-01-01 이후, 지역이 충북인 데이터 요청
# cur.execute("SELECT * FROM service where eq_date >= 2023/01/01 and (eq_location = '전남' or eq_location = '경북' or eq_location = '충북' or eq_location = '전북')")
cur.execute("SELECT * FROM service where eq_date >= '2023-01-01' and eq_location = '충북'")
nia = cur.fetchall()
# 데이터프레임 변환
df = pd.DataFrame(nia, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])

# %%
import folium
import json
# 폴리움 패키지 선언

# 지도 맵 ( GEO, JSON 데이터 선언 )
# 실행 시 위치를 변경해줘야 함
geo_path = 'C:\\Users\\starl\\Downloads\\데이터사이언스개론 82\\geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))   # 딕셔너리

folium.Choropleth(geo_data = geo_str,
data = df['level']).add_to(map)
# 폴리움 지도 시작점 설정
map = folium.Map(location=[34.43, 125.99], zoom_start=9,      
tiles='Stamen Toner') 

# 시각화할 상위 데이터 출력
print(df.head(10))

for n in df.index:
    folium.Marker(location=[df['addr1'][n], 
    df['addr2'][n]], popup=df['level'][n], icon=folium.Icon(color='green',icon='star')).add_to(map)
    # print(df['addr1'][n], df['addr2'][n])
# folium.Marker(location=[34.43, 125.99], icon=folium.Icon(color='blue',icon='star')
# ).add_to(map)
 # 지도 객체 생성
map
# 폴리움에 마커를 찍어서 저장
# Out:
#     ID        Date TimeStamp level    addr1     addr2 address
# 0  638  2023/05/23  00:28:35     1  36.69    127.78        충북
# 1  696  2023/05/06  11:39:10     1  36.33    127.75        충북
# 2  710  2023/05/01  09:06:30     1  36.33    127.75        충북
# 3  711  2023/04/30  19:03:29     1  36.32    127.75        충북
# 4  753  2023/04/19  09:43:38     1  36.33    127.65        충북
# 5  765  2023/04/15  14:29:24     1  36.35    127.87        충북
# 6  799  2023/04/03  01:04:03     1  36.37    127.61        충북
# 7  835  2023/03/16  08:14:07     1  36.51    127.85        충북
# 8  898  2023/02/11  08:22:01     2  36.52    127.85        충북
# 9  957  2023/01/15  01:56:28     1  36.88    127.87        충북
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
# ...

# %%
import folium
import json

# 위와 동일한 코드
geo_path = 'C:\\Users\\starl\\Downloads\\데이터사이언스개론 82\\geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))   # 딕셔너리

folium.Choropleth(geo_data = geo_str,
data = df['level']).add_to(map)

# , columns = [df.index, df['level']], fill_color = 'PuRd', key_on = 'ID'

# for n in df.index:
#     folium.Marker(location=[df['addr1'][n], 
#     df['addr2'][n]]).add_to(map)
    # print(df['addr1'][n], df['addr2'][n])
map = folium.Map(location=[34.43, 125.99], zoom_start=9,      
tiles='Stamen Toner') 

print(df.head(10))

# 위에서 선언한 지진 관련 데이터 재선언 후 가져오기
for n in df.index:
    folium.Marker(location=[df['addr1'][n], 
    df['addr2'][n]], popup=df['level'][n], icon=folium.Icon(color='green',icon='star')).add_to(map)
    # print(df['addr1'][n], df['addr2'][n])
# folium.Marker(location=[34.43, 125.99], icon=folium.Icon(color='blue',icon='star')
# ).add_to(map)
 # 지도 객체 생성
map

# %%
### 각 지진의 발생 빈도수 분석 :: 4개 지역
# 전남, 경북, 충남, 전북

# 데이터베이스에서 가져와서 각각의 데이터프레임에 저장
cur.execute('SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "전남"')
notea = cur.fetchall()
df1 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "경북"')
notea = cur.fetchall()
df2 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "충남"')
notea = cur.fetchall()
df3 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df4 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])

# %%
print(df1.head(10))
print(df2.head(10))
# Out:
#     ID        Date TimeStamp level    addr1     addr2 address
# 0  626  2023/05/27  02:32:12     1  35.46    126.81        전남
# 1  628  2023/05/26  20:39:54     1  35.46    126.81        전남
# 2  637  2023/05/24  05:26:46     1  35.04    124.92        전남
# 3  645  2023/05/19  21:08:33     1  34.43    125.99        전남
# 4  646  2023/05/19  16:34:13     1  34.43    125.99        전남
# 5  649  2023/05/19  00:23:33     1  34.93    127.17        전남
# 6  666  2023/05/12  17:04:54     1  34.79    127.45        전남
# 7  706  2023/05/02  19:08:12     1  35.09    125.07        전남
# 8  752  2023/04/19  13:40:19     1  34.07    124.60        전남
# 9  760  2023/04/17  17:45:02     1  35.41    125.97        전남
#     ID        Date TimeStamp level    addr1     addr2 address
# 0  635  2023/05/24  17:15:36     1  36.49    129.81        경북
# 1  665  2023/05/13  10:14:04     1  36.48    128.52        경북
# 2  751  2023/04/21  00:19:44     1  36.53    129.67        경북
# ...

# %%
### 각 지진의 발생 빈도수 분석 :: 4개 지역
# 전남, 경북, 충남, 전북

# 위와 동일
addr = "전남"
cur.execute(f'SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "mp"')
notea = cur.fetchall()
df1 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute(f'SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "mp"')
notea = cur.fetchall()
df2 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute(f'SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "mp"')
notea = cur.fetchall()
df3 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute(f'SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "mp"')
notea = cur.fetchall()
df4 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[211], line 5
#       1 ### 각 지진의 발생 빈도수 분석 :: 4개 지역
#       2 # 전남, 경북, 충남, 전북
#       4 addr = "전남"
# ----> 5 cur.execute(f'SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = {addr}')
#       6 notea = cur.fetchall()
#       7 df1 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
#
# File c:\Users\starl\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File c:\Users\starl\AppData\Local\Programs\Python\Python310\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
# ...

# %%
### 각 지진의 발생 빈도수 분석 :: 4개 지역
# 전남, 경북, 충남, 전북

# 각 지역별 데이터 가져오기 ( 지역 정보만 4개 지역으로 바꿔서 수행 )

# 2-8
cur.execute('SELECT * FROM service where eq_date >= "2017-01-01" and eq_date <= "2018-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df2 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2018-01-01" and eq_date <= "2019-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df3 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2019-01-01" and eq_date <= "2020-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df4 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2020-01-01" and eq_date <= "2021-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df5 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2021-01-01" and eq_date <= "2022-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df6 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2022-01-01" and eq_date <= "2023-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df7 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01" and eq_location = "전북"')
notea = cur.fetchall()
df8 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])

# %%
### 각 지진의 발생 빈도수 분석 :: 4개 지역
# 전국

# 2-8
cur.execute('SELECT * FROM service where eq_date >= "2017-01-01" and eq_date <= "2018-01-01"')
notea = cur.fetchall()
df2 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2018-01-01" and eq_date <= "2019-01-01"')
notea = cur.fetchall()
df3 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2019-01-01" and eq_date <= "2020-01-01"')
notea = cur.fetchall()
df4 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2020-01-01" and eq_date <= "2021-01-01"')
notea = cur.fetchall()
df5 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2021-01-01" and eq_date <= "2022-01-01"')
notea = cur.fetchall()
df6 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2022-01-01" and eq_date <= "2023-01-01"')
notea = cur.fetchall()
df7 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])
cur.execute('SELECT * FROM service where eq_date >= "2023-01-01" and eq_date <= "2024-01-01"')
notea = cur.fetchall()
df8 = pd.DataFrame(notea, columns=['ID','Date','TimeStamp','level','addr1','addr2','address'])

# %%
count2 = 0
for i in df2.index:
    count2 += 1
count3 = 0
for i in df3.index:
    count3 += 1
count4 = 0
for i in df4.index:
    count4 += 1
count5 = 0
for i in df5.index:
    count5 += 1
count6 = 0
for i in df6.index:
    count6 += 1
count7 = 0
for i in df7.index:
    count7 += 1
count8 = 0
for i in df8.index:
    count8 += 1

# 막대그래프 생성용 COUNT CODE ( index 방식이 편하기는 하나 오류 발생 )
print(count2, count3, count4, count5, count6, count7, count8)
# Out:
# 172 140 267 377 321 375 153

# %%
import seaborn as sns

# 데이터그리기
sns.set_theme(style="whitegrid") ## figure, axes 스타일
x = ['2017', '2018', '2019', '2020', '2021', '2022', '2023'] ## x축에 들어갈 범주형 변수
y = [count2, count3, count4, count5, count6, count7, count8] ## 각 범주에 해당하는 숫자
sns.barplot(x=x, y=y) ## 바 차트 생성
# Out:
# <Axes: >
